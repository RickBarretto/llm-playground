# %% [markdown]
# <a href="https://colab.research.google.com/github/RickBarretto/llm-playground/blob/main/playgrounds/gaia-4b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - Author: [Centro de Excelência em IA - UFG](https://huggingface.co/CEIA-UFG)
# - Source: [HuggingFace](https://huggingface.co/CEIA-UFG/Gemma-3-Gaia-PT-BR-4b-it)
# - License: [Gemma](https://ai.google.dev/gemma/terms)

# %%
# !pip install -U transformers

# %%
from transformers import pipeline

pipe = pipeline("text-generation", model="CEIA-UFG/Gemma-3-Gaia-PT-BR-4b-it", device_map="auto")

# %%
prompt = "Qual o seu nome?"

out = pipe(prompt, max_new_tokens=500, do_sample=True)
print(out[0]["generated_text"])
