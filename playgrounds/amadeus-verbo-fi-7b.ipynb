# %% [markdown]
# <a href="https://colab.research.google.com/github/RickBarretto/llm-playground/blob/main/playgrounds/amadeus-verbo-fi-7b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - Author: [Amadeus AI at Huggingface](https://huggingface.co/amadeusai)
# - Source: [Use Amadeus-Verbo-FI-Qwen2.5-7B-PT-BR-Instruct on Collab](https://huggingface.co/amadeusai/Amadeus-Verbo-FI-Qwen2.5-7B-PT-BR-Instruct/colab)
# - License: [Apache 2.0](https://huggingface.co/datasets/choosealicense/licenses/blob/main/markdown/apache-2.0.md)

# %%
# !pip install -U transformers

from transformers import pipeline

pipe = pipeline("text-generation", model="amadeusai/Amadeus-Verbo-FI-Qwen2.5-7B-PT-BR-Instruct")

# %%
prompt = "Escreva um poema no estilo de Gregório de Matos"
messages = [
    {"role": "user", "content": prompt},
]
pipe(messages)
