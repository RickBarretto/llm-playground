# %% [markdown]
# <a href="https://colab.research.google.com/github/RickBarretto/llm-playground/blob/main/notebooks/amadeus-verbo-fi-7b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U transformers

# %%
from transformers import pipeline

pipe = pipeline("text-generation", model="amadeusai/Amadeus-Verbo-FI-Qwen2.5-7B-PT-BR-Instruct")

# %%
prompt = "Escreva um poema no estilo de Gregório de Matos"
messages = [
    {"role": "user", "content": prompt},
]
pipe(messages)
